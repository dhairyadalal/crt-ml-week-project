# %%
import random 
from deap import base, creator, tools, algorithms
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from functools import reduce
import importlib
import datetime as dt
from datetime import datetime
from sklearn import preprocessing

from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error

from math import sqrt

# %%
date_format="%Y-%m-%d"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
DWJ = pd.read_csv("C:/Users/ciara/Downloads/DJI.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)



date_format="%d/%m/%Y"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
HD= pd.read_csv("C:/Users/ciara/Downloads/HD.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
CAT= pd.read_csv("C:/Users/ciara/Downloads/CAT.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
CVX= pd.read_csv("C:/Users/ciara/Downloads/CVX.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
XOM= pd.read_csv("C:/Users/ciara/Downloads/XOM.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
JPM= pd.read_csv("C:/Users/ciara/Downloads/JPM.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
INTC= pd.read_csv("C:/Users/ciara/Downloads/INTC.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
MMM= pd.read_csv("C:/Users/ciara/Downloads/MMM.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
MCD= pd.read_csv("C:/Users/ciara/Downloads/MCD.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
V= pd.read_csv("C:/Users/ciara/Downloads/V.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
WMT= pd.read_csv("C:/Users/ciara/Downloads/WMT.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
PFE= pd.read_csv("C:/Users/ciara/Downloads/PFE.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
MSFT= pd.read_csv("C:/Users/ciara/Downloads/MSFT.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
KO= pd.read_csv("C:/Users/ciara/Downloads/KO.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
AAPL= pd.read_csv("C:/Users/ciara/Downloads/AAPL.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
BA= pd.read_csv("C:/Users/ciara/Downloads/BA.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)
NKE= pd.read_csv("C:/Users/ciara/Downloads/NKE.csv", index_col="Date",
                  parse_dates=True, date_parser=date_parse)

# %%
NKE=NKE.rename(columns={"Close": "NKE_price"})
NKE=NKE["NKE_price"]
HD=HD.rename(columns={"Close": "HD_price"})
CAT=CAT.rename(columns={"Close": "CAT_price"})
CVX=CVX.rename(columns={"Close": "CVX_price"})
XOM=XOM.rename(columns={"Close": "XOM_price"})
JPM=JPM.rename(columns={"Close": "JPM_price"})
HD= HD["HD_price"]
CAT= CAT["CAT_price"]
CVX= CVX["CVX_price"]
XOM= XOM["XOM_price"]
JPM= JPM["JPM_price"]
portfolio_1=pd.merge(HD,CAT, left_index=True, right_index=True)
portfolio_1=pd.merge(portfolio_1, CVX, left_index=True, right_index=True)
portfolio_1=pd.merge(portfolio_1, XOM, left_index=True, right_index=True)
portfolio_1=pd.merge(portfolio_1, JPM, left_index=True, right_index=True)
portfolio_1


INTC=INTC.rename(columns={"Close": "INTC_price"})
INTC=INTC["INTC_price"]
MMM= MMM.rename(columns={"Close": "MMM_price"})
MMM= MMM["MMM_price"]
MCD= MCD.rename(columns={"Close": "MCD_price"})
MCD= MCD["MCD_price"]
V= V.rename(columns={"Close": "V_price"})
V= V["V_price"]
WMT= WMT.rename(columns={"Close": "WMT_price"})
WMT= WMT["WMT_price"]

portfolio_2=pd.merge(INTC,MMM, left_index=True, right_index=True)
portfolio_2=pd.merge(portfolio_2, MCD, left_index=True, right_index=True)
portfolio_2=pd.merge(portfolio_2, V, left_index=True, right_index=True)
portfolio_2=pd.merge(portfolio_2, WMT, left_index=True, right_index=True)


PFE= PFE.rename(columns={"Close": "PFE_price"})
PFE= PFE["PFE_price"]
MSFT= MSFT.rename(columns={"Close": "MSFT_price"})
MSFT= MSFT["MSFT_price"]
KO = KO.rename(columns={"Close": "KO_price"})
KO= KO["KO_price"]
AAPL= AAPL.rename(columns={"Close": "AAPL_price"})
AAPL= AAPL["AAPL_price"]
BA= BA.rename(columns={"Close": "BA_price"})
BA= BA["BA_price"]
portfolio_3=pd.merge(INTC,MMM, left_index=True, right_index=True)
portfolio_3=pd.merge(portfolio_3, MCD, left_index=True, right_index=True)
portfolio_3=pd.merge(portfolio_3, V, left_index=True, right_index=True)
portfolio_3=pd.merge(portfolio_3, WMT, left_index=True, right_index=True)

portfolio_4=pd.merge(AAPL,MSFT, left_index=True, right_index=True)
portfolio_4=pd.merge(portfolio_4, INTC, left_index=True, right_index=True)
portfolio_4=pd.merge(portfolio_4, KO, left_index=True, right_index=True)
portfolio_4=pd.merge(portfolio_4, V, left_index=True, right_index=True)

portfolio_5=pd.merge(AAPL,MSFT, left_index=True, right_index=True)
portfolio_5=pd.merge(portfolio_5, CAT, left_index=True, right_index=True)
portfolio_5=pd.merge(portfolio_5, CVX, left_index=True, right_index=True)
portfolio_5=pd.merge(portfolio_5, PFE, left_index=True, right_index=True)

# %%
#random gives us a way to generate random bits;

#deap this implements the functionality for evolutionary algorithms in python, we’ll use the following submodules
#base gives us access to the Toolbox and base Fitness;
#creator allows us to create our types;
#tools grants us access to the operators bank;
#algorithms enables us some ready generic evolutionary loops.


creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

# %%
ind = creator.Individual([1, 0, 1, 1, 0])

print(ind)
print(type(ind))
print(type(ind.fitness))
# Out:
# [1, 0, 1, 1, 0]
# <class 'deap.creator.Individual'>
# <class 'deap.creator.FitnessMax'>

# %%
toolbox = base.Toolbox()
toolbox.register("attr_bool", random.random)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, n=15)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
bit = toolbox.attr_bool()
ind = toolbox.individual()
pop = toolbox.population(n=48)

print("bit is of type %s and has value\n%s" % (type(bit), bit))
print("ind is of type %s and contains %d bits\n%s" % (type(ind), len(ind), ind))
print("pop is of type %s and contains %d individuals\n%s" % (type(pop), len(pop), pop))
# Out:
# bit is of type <class 'float'> and has value
# 0.5570190505364683
# ind is of type <class 'deap.creator.Individual'> and contains 15 bits
# [0.5962941576682215, 0.49310643805104115, 0.9323759616307313, 0.699538284888943, 0.5908642518848883, 0.8589304617114448, 0.22413096498427332, 0.4115080287964695, 0.7669800883544481, 0.4486060741177591, 0.13405268247186652, 0.49691318871784396, 0.6672611942662791, 0.7164457476748697, 0.13530989523515258]
# pop is of type <class 'list'> and contains 48 individuals
# [[0.3494642156312998, 0.23544557200511562, 0.8682468329195798, 0.8146615026873671, 0.888939524089959, 0.8109093536240158, 0.6797672862100166, 0.6007831050865721, 0.23928953717124768, 0.18134785447774038, 0.26479439692350704, 0.8107583976633745, 0.7265722724337714, 0.16433254705353084, 0.2798009399803575], [0.2784848725633309, 0.1717571498246121, 0.11447357916375334, 0.4499909038632436, 0.9620320135977712, 0.13601577928289077, 0.2922334265479044, 0.08132709186989273, 0.5486899756733299, 0.4889196376628302, 0.8737263631793417, 0.16250053590821267, 0.728946087056233, 0.15700951974222987, 0.49164109752666385], [0.3319469508370245, 0.4461755289846143, 0.841780331534979, 0.26112504123229296, 0.10159985682954698, 0.7763050231623683, 0.06768121744471467, 0.5332128669725987, 0.4665509832940553, 0.38590675925392237, 0.36838488480283293, 0.5685100409679811, 0.5473934778625112, 0.8157971047769245, 0.9131149669025463], [0.286321338383817, 0.6729689960770104, 0.8964662729089516, 0.15799289773751446, 0.014457847273417479, 0.8066582660010884, 0.6854904461200669, 0.8960197832836033, 0.21377091496066325, 0.8373622571555714, 0.07173939955522224, 0.6790455549002218, 0.5756996600385329, 0.870499553175314, 0.7525837395171564], [0.5472370498228146, 0.5706114842991709, 0.44254058121666173, 0.7581622760607033, 0.2519410098333027, 0.25076016306404814, 0.266642938646077, 0.9123476413554333, 0.17765764770600057, 0.19512308873064343, 0.9052625497205218, 0.47441309818915045, 0.39889027027458857, 0.16607639641760907, 0.4007119572398685], [0.8444012144140439, 0.006828397452988688, 0.5427513377389255, 0.5418684972527574, 0.8071732492477057, 0.6709982195189249, 0.1443453997216233, 0.7641521915279831, 0.5364259748430701, 0.3123227035868601, 0.38463091278784234, 0.3146669207004138, 0.06401869844715835, 0.6451220504564876, 0.3430992788020987], [0.7988783545574342, 0.9345708711814399, 0.04042992904028553, 0.5087473494950855, 0.45782803988722953, 0.4399780600616665, 0.601558234090232, 0.48261985084435155, 0.8763143407218185, 0.22142247107177127, 0.31271908577371155, 0.6302078760964854, 0.2741754091418872, 0.3401085353950415, 0.9831349509981958], [0.2547800300449753, 0.01447324825318208, 0.4141998440993936, 0.19354105060582083, 0.6387522454810486, 0.7483027766338576, 0.12038854093365536, 0.3872319395348922, 0.7537561640924715, 0.5242402043685425, 0.6985360699537184, 0.43874649224660045, 0.48464171240821485, 0.5336226157106472, 0.2836530212626033], [0.006337529602393421, 0.9509739433359419, 0.6065634254011694, 0.8452656997820397, 0.4201283159920667, 0.2002291253417039, 0.2848503426368465, 0.6711405296563957, 0.47985873397523093, 0.6526658820020258, 0.9317062007681054, 0.24159209149781857, 0.15223469547453106, 0.10983010142781247, 0.006177950998665693], [0.2927658769896264, 0.07432239163574161, 0.6866886326294734, 0.6836310934225831, 0.965824591259718, 0.5290842462096182, 0.6774038035669796, 0.2078574082434841, 0.44996303001997406, 0.8587256438248508, 0.7183820675650995, 0.3540314799676526, 0.4188097763164307, 0.139095122274559, 0.561556307766392], [0.13591464364701644, 0.6085786166842115, 0.28888265965590565, 0.7503610020367856, 0.7439276641688835, 0.5297816456986668, 0.7008921716190221, 0.728223209288757, 0.4060068861571302, 0.8637940233580435, 0.13415529259600023, 0.24259651156157747, 0.5138970379815664, 0.5537597793628326, 0.07430933343411561], [0.7082033148635238, 0.682503853695466, 0.8839003803316487, 0.8916942255671887, 0.3908503574016421, 0.8148120210428229, 0.9098461734693691, 0.4045993519108326, 0.02556206629826374, 0.39452355549789864, 0.7685421487136493, 0.6927336191452164, 0.38229710930868477, 0.36284954351163, 0.02910390506280769], [0.6026000795431282, 0.13713783423993942, 0.3595293941663197, 0.5571912130244921, 0.7247207711946881, 0.9740178217182118, 0.2751351098019744, 0.3459270439545974, 0.6687164674383879, 0.9156639776430876, 0.9915913515390219, 0.23654951286521086, 0.8093945339113787, 0.37182817708993665, 0.9553275043574723], [0.31535852530818753, 0 ...

# %%
def evalOneMax(individual,portfolio_1=portfolio_1, portfolio_2=portfolio_2,
             portfolio_3=portfolio_3,portfolio_4=portfolio_4,portfolio_5=portfolio_5):
    
    objective=np.dot(individual, DWJ)
    if ((np.dot(individual, portfolio_1)/np.dot(portfolio_2,individual))-1) >0:

        objective = np.dot(individual, portfolio_4)
    
   
    if ((np.dot(individual, portfolio_1)/np.dot(individual,portfolio_2))-1) >0 :
        
        objective = portfolio_1
      
    if ((np.dot(individual, portfolio_2)/np.dot(individual,portfolio_3))-1) >0 :
        
        objective = portfolio_2
        
    if ((np.dot(individual, portfolio_3)/np.dot(individual,portfolio_4))-1) >0 :
        
        objective = portfolio_3   
     
    if ((np.dot(individual, portfolio_4)/np.dot(individual,portfolio_5))-1) >0 :
        
        objective = portfolio_4
    
    if ((np.dot(individual, portfolio_5)/np.dot(individual,portfolio_1))-1) >0 :
        
        objective = portfolio_5
    
    return objective

# %%
toolbox.register("evaluate", evalOneMax)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.10)
toolbox.register("select", tools.selTournament, tournsize=3)

# %%
ind = toolbox.individual()
print(ind)
toolbox.mutate(ind)
print(ind)
# Out:
# [0.35081157305832755, 0.8273038899341866, 0.7600283674530842, 0.28990422059551635, 0.32979937232481005, 0.7949386230296607, 0.9596247841622959, 0.5745509032399083, 0.07592049351303976, 0.06049015241791256, 0.3220171092455495, 0.20956836124306155, 0.42918126948042024, 0.7688491171944936, 0.7540579318045595]
# [0.35081157305832755, 0.8273038899341866, 0.7600283674530842, 0.0, 0.32979937232481005, 0.7949386230296607, 0.9596247841622959, 0.5745509032399083, 0.07592049351303976, 0.06049015241791256, 0.3220171092455495, 0.0, 0.42918126948042024, 0.7688491171944936, 0.7540579318045595]

# %%
mutant = toolbox.clone(ind)
print(mutant is ind)
print(mutant == ind)
# Out:
# False
# True

# %%
def main():
    
    pop = toolbox.population(n=5000)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", numpy.mean)
    stats.register("min", numpy.min)
    stats.register("max", numpy.max)
    
    pop, logbook = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=10, stats=stats, halloffame=hof, verbose=True)
    
    return pop, logbook, hof

# %%
if __name__ == "__main__":
    import numpy
    pop, log, hof = main()
print("Best individual is: %s\nwith fitness: %s" % (hof[0], hof[0].fitness))



gen, avg, min_, max_ = log.select("gen", "avg", "min", "max")
plt.plot(gen, avg, label="average")
plt.plot(gen, min_, label="minimum")
plt.plot(gen, max_, label="maximum")
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.legend(loc="lower right")
plt.show()
